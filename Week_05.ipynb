# %% [markdown]
# # **Week 05**

# %% [markdown]
# # 17 : Resampling pada Data Deret Waktu (time series data)

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.1.3
# 1.26.2

# %% [markdown]
# ## Persiapan Data Frame

# %%
n_rows = 365 * 24
n_cols = 2
cols = ['col1', 'col2']

# Create a DataFrame with a datetime index
date_index = pd.date_range(start='2023-01-01', periods=n_rows, freq='H')
df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), columns=cols, index=date_index)

df.head()
# Out:
#                      col1  col2
# 2023-01-01 00:00:00    18     9
# 2023-01-01 01:00:00     3     2
# 2023-01-01 02:00:00    10     1
# 2023-01-01 03:00:00     8    14
# 2023-01-01 04:00:00    18    17

# %% [markdown]
# ## Resampling Data dengan Interval Monthly

# %%
df.resample('M')['col1'].sum().to_frame()
# Out:
#             col1
# 2023-01-31  7406
# 2023-02-28  6656
# 2023-03-31  7306
# 2023-04-30  7221
# 2023-05-31  7087
# 2023-06-30  7242
# 2023-07-31  7191
# 2023-08-31  7219
# 2023-09-30  7368
# 2023-10-31  7310
# 2023-11-30  7142
# 2023-12-31  7504

# %% [markdown]
# ## Resampling Data dengan Interval Daily

# %%
df.resample('D')['col1'].sum().to_frame()
# Out:
#             col1
# 2023-01-01   229
# 2023-01-02   232
# 2023-01-03   201
# 2023-01-04   193
# 2023-01-05   229
# ...          ...
# 2023-12-27   227
# 2023-12-28   255
# 2023-12-29   272
# 2023-12-30   258
# 2023-12-31   259
#
# [365 rows x 1 columns]

# %% [markdown]
# # 18 : Membentuk dummy Data Frame

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np

#Cek versi
print(pd.__version__)
print(np.__version__)
# Out:
# 2.1.3
# 1.26.2

# %% [markdown]
# ## Membentuk Data Frame dari Dictionary

# %%
pd.DataFrame({'col1':[1, 2, 3, 4], 
              'col2':[5, 6, 7, 8]})
# Out:
#    col1  col2
# 0     1     5
# 1     2     6
# 2     3     7
# 3     4     8

# %% [markdown]
# ## Membentuk Data Frame dari Numpy Array

# %%
n_rows = 5
n_cols = 3

arr = np.random.randint(1, 20, size=(n_rows, n_cols))
arr
# Out:
# array([[ 3,  8,  5],
#        [18, 11, 17],
#        [10, 16, 14],
#        [ 5,  4, 15],
#        [ 1,  1, 18]])

# %%
pd.DataFrame(arr, columns=tuple('ABC'))
# Out:
#     A   B   C
# 0   3   8   5
# 1  18  11  17
# 2  10  16  14
# 3   5   4  15
# 4   1   1  18

# %% [markdown]
# ## Membentuk Data Frame dengan Memanfaatkan pandas.util.testing

# %%
# Create a DataFrame with sample data
data = {
    'A': np.random.rand(5),
    'B': np.random.randint(1, 10, size=(5)),
    'C': np.random.choice(['X', 'Y', 'Z'], size=(5))
}

df = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df.head()
# Out:
#           A  B  C
# 0  0.175989  8  X
# 1  0.144405  2  X
# 2  0.352845  2  Y
# 3  0.647855  1  X
# 4  0.830177  6  Y

# %%
# Create a mixed data type DataFrame with sample data
data = {
    'A': [1, 2.5, 'foo', True, pd.to_datetime('2023-01-01')],
    'B': [1.1, 'bar', False, 3, np.nan],
    'C': [pd.Timedelta(days=1), 42, 'baz', 7.7, 'qux']
}

df = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df.head()
# Out:
#                      A      B                C
# 0                    1    1.1  1 days 00:00:00
# 1                  2.5    bar               42
# 2                  foo  False              baz
# 3                 True      3              7.7
# 4  2023-01-01 00:00:00    NaN              qux

# %%
# Create a time-based DataFrame with sample data
n_rows = 5
date_index = pd.date_range(start='2023-01-01', periods=n_rows, freq='D')

data = {
    'A': np.random.rand(n_rows),
    'B': np.random.randn(n_rows),
    'C': np.random.randint(1, 10, size=n_rows)
}

df = pd.DataFrame(data, index=date_index)

# Display the first few rows of the DataFrame
df.head()
# Out:
#                    A         B  C
# 2023-01-01  0.724960 -1.387137  2
# 2023-01-02  0.522664 -0.459761  5
# 2023-01-03  0.193145 -1.022740  8
# 2023-01-04  0.641370 -0.794624  3
# 2023-01-05  0.867376  0.551352  8

# %%
# Create a DataFrame with random data
data = {'A': np.random.rand(5), 'B': np.random.rand(5), 'C': np.random.rand(5)}
df = pd.DataFrame(data)

# Introduce some missing values
df.iloc[2:4, 0] = np.nan
df.iloc[1, 1] = np.nan
df.iloc[3, 2] = np.nan

# Display the DataFrame with missing values
df.head()
# Out:
#           A         B         C
# 0  0.982235  0.688978  0.451702
# 1  0.885425       NaN  0.553374
# 2       NaN  0.152755  0.017224
# 3       NaN  0.802850       NaN
# 4  0.888001  0.381040  0.452171

# %% [markdown]
# # 19 : Formatting tampilan Data Frame

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.1.3
# 1.26.2

# %% [markdown]
# ## Persiapan Data Frame

# %%
n_rows = 5
n_cols = 2
cols = ['omset', 'operasional']

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    omset  operasional
# 0     13            8
# 1      2           15
# 2      5            9
# 3      1            2
# 4     10            2

# %%
df['omset'] = df['omset'] * 100_000
df['operasional'] = df['operasional'] * 10_000
df
# Out:
#      omset  operasional
# 0  1300000        80000
# 1   200000       150000
# 2   500000        90000
# 3   100000        20000
# 4  1000000        20000

# %%
n_rows = 365  # or any other value

# Create a DataFrame with random data
data = {'A': np.random.rand(n_rows), 'B': np.random.rand(n_rows), 'C': np.random.rand(n_rows)}
df = pd.DataFrame(data)

# Create a date index using pd.date_range
date_index = pd.date_range(start='2023-01-01', periods=n_rows, freq='D')

# Set the date index to the DataFrame
df.index = date_index

# Reset the index and rename the original index column
df = df.reset_index().rename(columns={'index': 'tanggal'})

df
# Out:
#        tanggal         A         B         C
# 0   2023-01-01  0.541687  0.013667  0.971747
# 1   2023-01-02  0.737038  0.948785  0.985587
# 2   2023-01-03  0.683244  0.661411  0.551344
# 3   2023-01-04  0.663888  0.137486  0.144069
# 4   2023-01-05  0.767440  0.256624  0.098168
# ..         ...       ...       ...       ...
# 360 2023-12-27  0.998419  0.154749  0.869153
# 361 2023-12-28  0.681456  0.751978  0.782006
# 362 2023-12-29  0.898697  0.511536  0.273186
# 363 2023-12-30  0.130515  0.953377  0.295301
# 364 2023-12-31  0.939435  0.449201  0.582615
#
# [365 rows x 4 columns]

# %% [markdown]
# ## Melakukan formatting tampilan Data Frame

# %%
formatku = {'tanggal':'{:%d/%m/%y}', 
            'operasional':'Rp {:.2f}',
            'omset':'Rp {:.2f}'}

laporan = df.style.format(formatku)
laporan # laporan bukan objek dataframe
# Out:
# <style type="text/css">
# </style>
# <table id="T_6506d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6506d_level0_col0" class="col_heading level0 col0" >tanggal</th>
#       <th id="T_6506d_level0_col1" class="col_heading level0 col1" >A</th>
#       <th id="T_6506d_level0_col2" class="col_heading level0 col2" >B</th>
#       <th id="T_6506d_level0_col3" class="col_heading level0 col3" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6506d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6506d_row0_col0" class="data row0 col0" >01/01/23</td>
#       <td id="T_6506d_row0_col1" class="data row0 col1" >0.159663</td>
#       <td id="T_6506d_row0_col2" class="data row0 col2" >0.309672</td>
#       <td id="T_6506d_row0_col3" class="data row0 col3" >0.959025</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6506d_row1_col0" class="data row1 col0" >02/01/23</td>
#       <td id="T_6506d_row1_col1" class="data row1 col1" >0.459512</td>
#       <td id="T_6506d_row1_col2" class="data row1 col2" >0.577328</td>
#       <td id="T_6506d_row1_col3" class="data row1 col3" >0.696607</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6506d_row2_col0" class="data row2 col0" >03/01/23</td>
#       <td id="T_6506d_row2_col1" class="data row2 col1" >0.257346</td>
#       <td id="T_6506d_row2_col2" class="data row2 col2" >0.196452</td>
#       <td id="T_6506d_row2_col3" class="data row2 col3" >0.239440</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6506d_row3_col0" class="data row3 col0" >04/01/23</td>
#       <td id="T_6506d_row3_col1" class="data row3 col1" >0.232222</td>
#       <td id="T_6506d_row3_col2" class="data row3 col2" >0.725071</td>
#       <td id="T_6506d_row3_col3" class="data row3 col3" >0.829243</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6506d_row4_col0" class="data row4 col0" >05/01/23</td>
#       <td id="T_6506d_row4_col1" class="data row4 col1" >0.067874</td>
#       <td id="T_6506d_row4_col2" class="data row4 col2" >0.730593</td>
#       <td id="T_6506d_row4_col3" class="data row4 col3" >0.604639</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6506d_row5_col0" class="data row5 col0" >06/01/23</td>
#       <td id="T_6506d_row5_col1" class="data row5 col1" >0.099758</td>
#       <td id="T_6506d_row5_col2" class="data row5 col2" >0.523302</td>
#       <td id="T_6506d_row5_col3" class="data row5 col3" >0.304965</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6506d_row6_col0" class="data row6 col0" >07/01/23</td>
#       <td id="T_6506d_row6_col1" class="data row6 col1" >0.950697</td>
#       <td id="T_6506d_row6_col2" class="data row6 col2" >0.790473</td>
#       <td id="T_6506d_row6_col3" class="data row6 col3" >0.999866</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6506d_row7_col0" class="data row7 col0" >08/01/23</td>
#       <td id="T_6506d_row7_col1" class="data row7 col1" >0.624114</td>
#       <td id="T_6506d_row7_col2" class="data row7 col2" >0.274115</td>
#       <td id="T_6506d_row7_col3" class="data row7 col3" >0.781400</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6506d_row8_col0" class="data row8 col0" >09/01/23</td>
#       <td id="T_6506d_row8_col1" class="data row8 col1" >0.610404</td>
#       <td id="T_6506d_row8_col2" class="data row8 col2" >0.588373</td>
#       <td id="T_6506d_row8_col3" class="data row8 col3" >0.899555</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6506d_row9_col0" class="data row9 col0" >10/01/23</td>
#       <td id="T_6506d_row9_col1" class="data row9 col1" >0.048132</td>
#       <td id="T_6506d_row9_col2" class="data row9 col2" >0.271666</td>
#       <td id="T_6506d_row9_col3" class="data row9 col3" >0.611627</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6506d_row10_col0" class="data row10 col0" >11/01/23</td>
#       <td id="T_6506d_row10_col1" class="data row10 col1" >0.941354</td>
#       <td id="T_6506d_row10_col2" class="data row10 col2" >0.899237</td>
#       <td id="T_6506d_row10_col3" class="data row10 col3" >0.738553</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6506d_row11_col0" class="data row11 col0" >12/01/23</td>
#       <td id="T_6506d_row11_col1" class="data row11 col1" >0.051155</td>
#       <td id="T_6506d_row11_col2" class="data row11 col2" >0.886114</td>
#       <td id="T_6506d_row11_col3" class="data row11 col3" >0.130267</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6506d_row12_col0" class="data row12 col0" >13/01/23</td>
#       <td id="T_6506d_row12_col1" class="data row12 col1" >0.334201</td>
#       <td id="T_6506d_row12_col2" class="data row12 col2" >0.226591</td>
#       <td id="T_6506d_row12_col3" class="data row12 col3" >0.426191</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6506d_row13_col0" class="data row13 col0" >14/01/23</td>
#       <td id="T_6506d_row13_col1" class="data row13 col1" >0.626368</td>
#       <td id="T_6506d_row13_col2" class="data row13 col2" >0.404894</td>
#       <td id="T_6506d_row13_col3" class="data row13 col3" >0.917179</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6506d_row14_col0" class="data row14 col0" >15/01/23</td>
#       <td id="T_6506d_row14_col1" class="data row14 col1" >0.592086</td>
#       <td id="T_6506d_row14_col2" class="data row14 col2" >0.214944</td>
#       <td id="T_6506d_row14_col3" class="data row14 col3" >0.101105</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6506d_row15_col0" class="data row15 col0" >16/01/23</td>
#       <td id="T_6506d_row15_col1" class="data row15 col1" >0.111681</td>
#       <td id="T_6506d_row15_col2" class="data row15 col2" >0.709107</td>
#       <td id="T_6506d_row15_col3" class="data row15 col3" >0.862399</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6506d_row16_col0" class="data row16 col0" >17/01/23</td>
#       <td id="T_6506d_row16_col1" class="data row16 col1" >0.432442</td>
#       <td id="T_6506d_row16_col2" class="data row16 col2" >0.053567</td>
#       <td id="T_6506d_row16_col3" class="data row16 col3" >0.773858</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6506d_row17_col0" class="data row17 col0" >18/01/23</td>
#       <td id="T_6506d_row17_col1" class="data row17 col1" >0.363620</td>
#       <td id="T_6506d_row17_col2" class="data row17 col2" >0.840902</td>
#       <td id="T_6506d_row17_col3" class="data row17 col3" >0.773230</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6506d_row18_col0" class="data row18 col0" >19/01/23</td>
#       <td id="T_6506d_row18_col1" class="data row18 col1" >0.114104</td>
#       <td id="T_6506d_row18_col2" class="data row18 col2" >0.623041</td>
#       <td id="T_6506d_row18_col3" class="data row18 col3" >0.980850</td>
#     </tr>
#     <tr>
#       <th id="T_6506d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6506d_row19_col0" class="data row19 col0" >20/01/23</td>
#       <td id="T_6506d_row19_col1" class="data row19 col1" >0.495781</td>
#       <td id="T_6506d_row19_col2

# %%
type(laporan)
# Out:
# pandas.io.formats.style.Styler

# %%
laporan.hide_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 laporan.hide_index()
#
# AttributeError: 'Styler' object has no attribute 'hide_index'

# %% [markdown]
# - Memberi keterangan

# %%
laporan.set_caption('Data Omset dan Operasional')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c0e75_">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c0e75_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_c0e75_row0_col1" class="data row0 col1" >Rp 1200000.00</td>
#       <td id="T_c0e75_row0_col2" class="data row0 col2" >Rp 130000.00</td>
#     </tr>
#     <tr>
#       <td id="T_c0e75_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_c0e75_row1_col1" class="data row1 col1" >Rp 500000.00</td>
#       <td id="T_c0e75_row1_col2" class="data row1 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <td id="T_c0e75_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_c0e75_row2_col1" class="data row2 col1" >Rp 1100000.00</td>
#       <td id="T_c0e75_row2_col2" class="data row2 col2" >Rp 50000.00</td>
#     </tr>
#     <tr>
#       <td id="T_c0e75_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_c0e75_row3_col1" class="data row3 col1" >Rp 1200000.00</td>
#       <td id="T_c0e75_row3_col2" class="data row3 col2" >Rp 150000.00</td>
#     </tr>
#     <tr>
#       <td id="T_c0e75_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_c0e75_row4_col1" class="data row4 col1" >Rp 1500000.00</td>
#       <td id="T_c0e75_row4_col2" class="data row4 col2" >Rp 80000.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Memberi penanda warna pada dataframe

# %%
laporan.highlight_min('omset', color='pink')
laporan.highlight_max('omset', color='lightgreen')

laporan.highlight_min('operasional', color='lightblue')
laporan.highlight_max('operasional', color='grey')
# Out:
# <style type="text/css">
# #T_c0e75_row1_col1 {
#   background-color: pink;
# }
# #T_c0e75_row2_col2 {
#   background-color: lightblue;
# }
# #T_c0e75_row3_col2 {
#   background-color: grey;
# }
# #T_c0e75_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c0e75_">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c0e75_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_c0e75_row0_col1" class="data row0 col1" >Rp 1200000.00</td>
#       <td id="T_c0e75_row0_col2" class="data row0 col2" >Rp 130000.00</td>
#     </tr>
#     <tr>
#       <td id="T_c0e75_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_c0e75_row1_col1" class="data row1 col1" >Rp 500000.00</td>
#       <td id="T_c0e75_row1_col2" class="data row1 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <td id="T_c0e75_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_c0e75_row2_col1" class="data row2 col1" >Rp 1100000.00</td>
#       <td id="T_c0e75_row2_col2" class="data row2 col2" >Rp 50000.00</td>
#     </tr>
#     <tr>
#       <td id="T_c0e75_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_c0e75_row3_col1" class="data row3 col1" >Rp 1200000.00</td>
#       <td id="T_c0e75_row3_col2" class="data row3 col2" >Rp 150000.00</td>
#     </tr>
#     <tr>
#       <td id="T_c0e75_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_c0e75_row4_col1" class="data row4 col1" >Rp 1500000.00</td>
#       <td id="T_c0e75_row4_col2" class="data row4 col2" >Rp 80000.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **#20 Menggabungkan (merge) Dua Data Frame Secara Berdampingan**
# Source : [Indonesia Belajar](https://youtu.be/AldqObRhkDU)

# %% [markdown]
# # Import Modules

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 1.3.4

# %% [markdown]
# - Membuat 2 buah dataframe
# - Masing-masing dataframe akan memiliki dua buah dictionary

# %%
d1 = {'col1':[1, 2, 3], 
      'col2':[10, 20, 30]}
df1 = pd.DataFrame(d1)
df1
# Out:
#    col1  col2
# 0     1    10
# 1     2    20
# 2     3    30

# %%
d2 = {'col3':[4, 5, 6], 
      'col4':[40, 50, 60]}
df2 = pd.DataFrame(d2)
df2
# Out:
#    col3  col4
# 0     4    40
# 1     5    50
# 2     6    60

# %% [markdown]
# - Berbeda dengan trick sebelumnya
# - Kali ini, kita hanya perlu menambahkan arguments True pada parameter left_index dan right_index.

# %%
df = pd.merge(df1, df2, left_index=True, right_index=True)
df
# Out:
#    col1  col2  col3  col4
# 0     1    10     4    40
# 1     2    20     5    50
# 2     3    30     6    60
